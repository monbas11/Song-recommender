# %%
from tkinter import messagebox
# !pip install yellowbrick
#Import the necesary libraries
import pandas as pd
import numpy as np
import tkinter as tk
from tkinter import messagebox
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
import dotenv
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
warnings.filterwarnings("ignore")




data = pd.read_csv(r"C:\Users\basil\OneDrive\Escritorio\Ironhack\labs\DB-recomender.csv")
data
# Out:
# Requirement already satisfied: yellowbrick in c:\users\basil\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (3.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.3.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.24.3)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\basil\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basil\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\basil\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
#                              song         artist  danceability  energy  key  \
# 0                    Don't Change           INXS         0.206   0.810    9
# 1                            Halo        Beyoncé         0.508   0.720   11
# 2                    It's My Life       Bon Jovi         0.551   0.913    0
# 3           Where Did Our Love Go   The Supremes         0.566   0.490    0
# 4                  Ordinary World    Duran Duran         0.472   0.652    1
# ...                           ...            ...           ...     ...  ...
# 1007                      Work It  Missy Elliott         0.884   0.677    1
# 1008                    Anti-Hero   Taylor Swift         0.637   0.643    4
# 1009  Never Gonna Not Dance Again           P!nk         0.668   0.802    5
# 1010                    TRUSTFALL           P!nk         0.636   0.888    8
# 1011                      My Hero   Foo Fighters         0.398   0.927    9
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -6.492     1       0.0423      0.000059          0.064400    0.0855
# 1       -5.908     0       0.0628      0.272000          0.000000    0.0563
# 2       -4.063     0       0.0466      0.026300          0.000013    0.3470
# 3      -10.867     1       0.0414      0.791000          0.000014    0.0919
# 4      -10.171     0       0.0305      0.013100          0.000011    0.1400
# ...        ...   ...          ...           ...               ...       ...
# 1007    -5.603     1       0.2830      0.077800          0.000000    0.0732
# 1008    -6.571     1       0.0519      0.130000          0.000002    0.1420
# 1009    -4.005     0       0.0917      0.027300          0.000000    0.1630
# 1010    -3.889     1       0.0945      0.001620          0.000216    0.1470
# 1011    -4.212     1       0.0567      0.000062          0.000177    0.0575
#
#       valence    tempo            type                      id  \
# 0       0.155  163.552  audio_features  2j7z87EnqB1NFQts2db0VR
# 1       0.472   79.983  audio_features  4JehYebiI9JE8sR8MisGVb
# 2       0.544  119.992  audio_features  0v1XpBHnsbkCn7iJ9Ucr1l
# 3       0.847  134.934  audio_features  69RH84na5iUNwrwxpgjC5j
# 4       0.401  140.124  audio_features  0wokCRaKD0zPNhMRXAgVsr
# ...       ...      ...             ...                     ...
# 1007    0.584  101.868  audio_features  3jagJCUbdqhDSPuxP8cAqF
# 1008    0.533   97.008  audio_features  0V3wPSX9ygBnCm8psDIegu
# 1009    0.769  113.796  audio_features  6sZo5nJIsFWXefRCCexpx0
# 1010    0.250  122.032  audio_features  4FWbsd91QSvgr1dSWwW51e
# 1011    0.311   77.106  audio_features  4dVbhS6OiYvFikshyaQaCN
#
#                                        uri  \
# 0     spotify:track:2j7z87EnqB1NFQts2db0VR
# 1     spotify:track:4JehYebiI9JE8sR8MisGVb
# 2     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l
# 3     spotify:track:69RH84na5iUNwrwxpgjC5j
# 4     spotify:track:0wokCRaKD0zPNhMRXAgVsr
# ...                                    ...
# 1007  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 1008  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1009  spotify:track:6sZo5nJIsFWXefRCCexpx0
# 1010  spotify:track:4FWbsd91QSvgr1dSWwW51e
# 1011  spotify:track:4dVbhS6OiYvFikshyaQaCN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2j7z87EnqB1N...
# 1     https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 2     https://api.spotify.com/v1/tracks/0v1XpBHnsbkC...
# 3     https://api.spotify.com/v1/tracks/69RH84na5iUN...
# 4     https://api.spotify.com/v1/tracks/0wokCRaKD0zP...
# ...                                                 ...
# 1007  https://api.spotify.com/v1/tracks/3jagJCUbdqhD...
# 1008  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1009  https://api.spotify.com/v1/tracks/6sZo5nJIsFWX...
# 1010  https://api.spotify.com/v1/tracks/4FWbsd91QSvg...
# 1011  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2j7z...       268200
# 1     https://api.spotify.com/v1/audio-analysis/4Jeh...       261640
# 2     https://api.spotify.com/v1/audio-analysis/0v1X...       224493
# 3     https://api.spotify.com/v1/audio-analysis/69RH...       153333
# 4     https://api.spotify.com/v1/audio-analysis/0wok...       340200
# ...                                                 ...          ...
# 1007  https://api.spotify.com/v1/audio-analysis/3jag...       263227
# 1008  https://api.spotify.com/v1/audio-analysis/0V3w...       200690
# 1009  https://api.spotify.com/v1/audio-analysis/6sZo...       225789
# 1010  https://api.spotify.com/v1/audio-analysis/4FWb...       237200
# 1011  https://api.spotify.com/v1/audio-analysis/4dVb...       260027
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1007               4
# 1008               4
# 1009               4
# 1010               4
# 1011               4
#
# [1012 rows x 20 columns]

# %%
# Verifica si hay duplicados basados en todas las columnas
duplicados = data[data.duplicated()]

# Verifica si hay duplicados basados en columnas específicas, por ejemplo, título y artista
duplicados_especificos = data[data.duplicated(['song', 'artist'])]

# Muestra los registros duplicados
print(duplicados)
# Out:
#                                                 song           artist  \
# 618  My Heart Will Go On - Love Theme from "Titanic"      Céline Dion
# 685                         I'm Gonna Be (500 Miles)  The Proclaimers
# 867                                       The Reflex      Duran Duran
# 875                                        Jailbreak            AC/DC
# 914               Somebody To Love - Remastered 2011            Queen
# 944                                      Sex on Fire    Kings of Leon
# 971                                April Sun in Cuba           Dragon
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 618         0.428   0.276    4   -11.729     1       0.0312       0.73200
# 685         0.851   0.551    4    -5.177     1       0.0396       0.15100
# 867         0.556   0.900    0    -6.110     1       0.0970       0.12300
# 875         0.572   0.835    9    -5.552     1       0.0790       0.00953
# 914         0.406   0.698    8    -7.024     1       0.0624       0.18600
# 944         0.542   0.905    9    -5.653     1       0.0540       0.00172
# 971         0.786   0.552    2   -13.885     1       0.0658       0.06420
#
#      instrumentalness  liveness  valence    tempo            type  \
# 618          0.000005    0.1170   0.0382   99.195  audio_features
# 685          0.000000    0.0827   0.8070  131.922  audio_features
# 867          0.000000    0.5710   0.8040  126.686  audio_features
# 875          0.014400    0.0120   0.5910  131.567  audio_features
# 914          0.000000    0.2330   0.3330  109.266  audio_features
# 944          0.010400    0.1360   0.3740  153.398  audio_features
# 971          0.000031    0.2990   0.9050  121.422  audio_features
#
#                          id                                   uri  \
# 618  33LC84JgLvK2KuW43MfaNq  spotify:track:33LC84JgLvK2KuW43MfaNq
# 685  66S14BkJDxgkYxLl5DCqOz  spotify:track:66S14BkJDxgkYxLl5DCqOz
# 867  0OsWMTxDjtpmJjX43113oq  spotify:track:0OsWMTxDjtpmJjX43113oq
# 875  5UKeFkVeUfvP6S43I8s9mt  spotify:track:5UKeFkVeUfvP6S43I8s9mt
# 914  4rDbp1vnvEhieiccprPMdI  spotify:track:4rDbp1vnvEhieiccprPMdI
# 944  0ntQJM78wzOLVeCUAW7Y45  spotify:track:0ntQJM78wzOLVeCUAW7Y45
# 971  0NKv1n25UpKKhZbp5UVV6P  spotify:track:0NKv1n25UpKKhZbp5UVV6P
#
#                                             track_href  \
# 618  https://api.spotify.com/v1/tracks/33LC84JgLvK2...
# 685  https://api.spotify.com/v1/tracks/66S14BkJDxgk...
# 867  https://api.spotify.com/v1/tracks/0OsWMTxDjtpm...
# 875  https://api.spotify.com/v1/tracks/5UKeFkVeUfvP...
# 914  https://api.spotify.com/v1/tracks/4rDbp1vnvEhi...
# 944  https://api.spotify.com/v1/tracks/0ntQJM78wzOL...
# 971  https://api.spotify.com/v1/tracks/0NKv1n25UpKK...
#
#                                           analysis_url  duration_ms  \
# 618  https://api.spotify.com/v1/audio-analysis/33LC...       280000
# 685  https://api.spotify.com/v1/audio-analysis/66S1...       219467
# 867  https://api.spotify.com/v1/audio-analysis/0OsW...       266933
# 875  https://api.spotify.com/v1/audio-analysis/5UKe...       280960
# 914  https://api.spotify.com/v1/audio-analysis/4rDb...       296480
# 944  https://api.spotify.com/v1/audio-analysis/0ntQ...       203347
# 971  https://api.spotify.com/v1/audio-analysis/0NKv...       207960
#
#      time_signature
# 618               1
# 685               4
# 867               4
# 875               4
# 914               3
# 944               4
# 971               4

# %%
# Elimina los duplicados basados en título y artista
data.drop_duplicates(subset=['song', 'artist'], inplace=True)

# Muestra el DataFrame sin duplicados
print(data)
# Out:
#                              song         artist  danceability  energy  key  \
# 0                    Don't Change           INXS         0.206   0.810    9
# 1                            Halo        Beyoncé         0.508   0.720   11
# 2                    It's My Life       Bon Jovi         0.551   0.913    0
# 3           Where Did Our Love Go   The Supremes         0.566   0.490    0
# 4                  Ordinary World    Duran Duran         0.472   0.652    1
# ...                           ...            ...           ...     ...  ...
# 1007                      Work It  Missy Elliott         0.884   0.677    1
# 1008                    Anti-Hero   Taylor Swift         0.637   0.643    4
# 1009  Never Gonna Not Dance Again           P!nk         0.668   0.802    5
# 1010                    TRUSTFALL           P!nk         0.636   0.888    8
# 1011                      My Hero   Foo Fighters         0.398   0.927    9
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -6.492     1       0.0423      0.000059          0.064400    0.0855
# 1       -5.908     0       0.0628      0.272000          0.000000    0.0563
# 2       -4.063     0       0.0466      0.026300          0.000013    0.3470
# 3      -10.867     1       0.0414      0.791000          0.000014    0.0919
# 4      -10.171     0       0.0305      0.013100          0.000011    0.1400
# ...        ...   ...          ...           ...               ...       ...
# 1007    -5.603     1       0.2830      0.077800          0.000000    0.0732
# 1008    -6.571     1       0.0519      0.130000          0.000002    0.1420
# 1009    -4.005     0       0.0917      0.027300          0.000000    0.1630
# 1010    -3.889     1       0.0945      0.001620          0.000216    0.1470
# 1011    -4.212     1       0.0567      0.000062          0.000177    0.0575
#
#       valence    tempo            type                      id  \
# 0       0.155  163.552  audio_features  2j7z87EnqB1NFQts2db0VR
# 1       0.472   79.983  audio_features  4JehYebiI9JE8sR8MisGVb
# 2       0.544  119.992  audio_features  0v1XpBHnsbkCn7iJ9Ucr1l
# 3       0.847  134.934  audio_features  69RH84na5iUNwrwxpgjC5j
# 4       0.401  140.124  audio_features  0wokCRaKD0zPNhMRXAgVsr
# ...       ...      ...             ...                     ...
# 1007    0.584  101.868  audio_features  3jagJCUbdqhDSPuxP8cAqF
# 1008    0.533   97.008  audio_features  0V3wPSX9ygBnCm8psDIegu
# 1009    0.769  113.796  audio_features  6sZo5nJIsFWXefRCCexpx0
# 1010    0.250  122.032  audio_features  4FWbsd91QSvgr1dSWwW51e
# 1011    0.311   77.106  audio_features  4dVbhS6OiYvFikshyaQaCN
#
#                                        uri  \
# 0     spotify:track:2j7z87EnqB1NFQts2db0VR
# 1     spotify:track:4JehYebiI9JE8sR8MisGVb
# 2     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l
# 3     spotify:track:69RH84na5iUNwrwxpgjC5j
# 4     spotify:track:0wokCRaKD0zPNhMRXAgVsr
# ...                                    ...
# 1007  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 1008  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1009  spotify:track:6sZo5nJIsFWXefRCCexpx0
# 1010  spotify:track:4FWbsd91QSvgr1dSWwW51e
# 1011  spotify:track:4dVbhS6OiYvFikshyaQaCN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2j7z87EnqB1N...
# 1     https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 2     https://api.spotify.com/v1/tracks/0v1XpBHnsbkC...
# 3     https://api.spotify.com/v1/tracks/69RH84na5iUN...
# 4     https://api.spotify.com/v1/tracks/0wokCRaKD0zP...
# ...                                                 ...
# 1007  https://api.spotify.com/v1/tracks/3jagJCUbdqhD...
# 1008  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1009  https://api.spotify.com/v1/tracks/6sZo5nJIsFWX...
# 1010  https://api.spotify.com/v1/tracks/4FWbsd91QSvg...
# 1011  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2j7z...       268200
# 1     https://api.spotify.com/v1/audio-analysis/4Jeh...       261640
# 2     https://api.spotify.com/v1/audio-analysis/0v1X...       224493
# 3     https://api.spotify.com/v1/audio-analysis/69RH...       153333
# 4     https://api.spotify.com/v1/audio-analysis/0wok...       340200
# ...                                                 ...          ...
# 1007  https://api.spotify.com/v1/audio-analysis/3jag...       263227
# 1008  https://api.spotify.com/v1/audio-analysis/0V3w...       200690
# 1009  https://api.spotify.com/v1/audio-analysis/6sZo...       225789
# 1010  https://api.spotify.com/v1/audio-analysis/4FWb...       237200
# 1011  https://api.spotify.com/v1/audio-analysis/4dVb...       260027
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1007               4
# 1008               4
# 1009               4
# 1010               4
# 1011               4
#
# [1004 rows x 20 columns]

# %%
data
# Out:
#                              song         artist  danceability  energy  key  \
# 0                    Don't Change           INXS         0.206   0.810    9
# 1                            Halo        Beyoncé         0.508   0.720   11
# 2                    It's My Life       Bon Jovi         0.551   0.913    0
# 3           Where Did Our Love Go   The Supremes         0.566   0.490    0
# 4                  Ordinary World    Duran Duran         0.472   0.652    1
# ...                           ...            ...           ...     ...  ...
# 1007                      Work It  Missy Elliott         0.884   0.677    1
# 1008                    Anti-Hero   Taylor Swift         0.637   0.643    4
# 1009  Never Gonna Not Dance Again           P!nk         0.668   0.802    5
# 1010                    TRUSTFALL           P!nk         0.636   0.888    8
# 1011                      My Hero   Foo Fighters         0.398   0.927    9
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -6.492     1       0.0423      0.000059          0.064400    0.0855
# 1       -5.908     0       0.0628      0.272000          0.000000    0.0563
# 2       -4.063     0       0.0466      0.026300          0.000013    0.3470
# 3      -10.867     1       0.0414      0.791000          0.000014    0.0919
# 4      -10.171     0       0.0305      0.013100          0.000011    0.1400
# ...        ...   ...          ...           ...               ...       ...
# 1007    -5.603     1       0.2830      0.077800          0.000000    0.0732
# 1008    -6.571     1       0.0519      0.130000          0.000002    0.1420
# 1009    -4.005     0       0.0917      0.027300          0.000000    0.1630
# 1010    -3.889     1       0.0945      0.001620          0.000216    0.1470
# 1011    -4.212     1       0.0567      0.000062          0.000177    0.0575
#
#       valence    tempo            type                      id  \
# 0       0.155  163.552  audio_features  2j7z87EnqB1NFQts2db0VR
# 1       0.472   79.983  audio_features  4JehYebiI9JE8sR8MisGVb
# 2       0.544  119.992  audio_features  0v1XpBHnsbkCn7iJ9Ucr1l
# 3       0.847  134.934  audio_features  69RH84na5iUNwrwxpgjC5j
# 4       0.401  140.124  audio_features  0wokCRaKD0zPNhMRXAgVsr
# ...       ...      ...             ...                     ...
# 1007    0.584  101.868  audio_features  3jagJCUbdqhDSPuxP8cAqF
# 1008    0.533   97.008  audio_features  0V3wPSX9ygBnCm8psDIegu
# 1009    0.769  113.796  audio_features  6sZo5nJIsFWXefRCCexpx0
# 1010    0.250  122.032  audio_features  4FWbsd91QSvgr1dSWwW51e
# 1011    0.311   77.106  audio_features  4dVbhS6OiYvFikshyaQaCN
#
#                                        uri  \
# 0     spotify:track:2j7z87EnqB1NFQts2db0VR
# 1     spotify:track:4JehYebiI9JE8sR8MisGVb
# 2     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l
# 3     spotify:track:69RH84na5iUNwrwxpgjC5j
# 4     spotify:track:0wokCRaKD0zPNhMRXAgVsr
# ...                                    ...
# 1007  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 1008  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1009  spotify:track:6sZo5nJIsFWXefRCCexpx0
# 1010  spotify:track:4FWbsd91QSvgr1dSWwW51e
# 1011  spotify:track:4dVbhS6OiYvFikshyaQaCN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2j7z87EnqB1N...
# 1     https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 2     https://api.spotify.com/v1/tracks/0v1XpBHnsbkC...
# 3     https://api.spotify.com/v1/tracks/69RH84na5iUN...
# 4     https://api.spotify.com/v1/tracks/0wokCRaKD0zP...
# ...                                                 ...
# 1007  https://api.spotify.com/v1/tracks/3jagJCUbdqhD...
# 1008  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1009  https://api.spotify.com/v1/tracks/6sZo5nJIsFWX...
# 1010  https://api.spotify.com/v1/tracks/4FWbsd91QSvg...
# 1011  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2j7z...       268200
# 1     https://api.spotify.com/v1/audio-analysis/4Jeh...       261640
# 2     https://api.spotify.com/v1/audio-analysis/0v1X...       224493
# 3     https://api.spotify.com/v1/audio-analysis/69RH...       153333
# 4     https://api.spotify.com/v1/audio-analysis/0wok...       340200
# ...                                                 ...          ...
# 1007  https://api.spotify.com/v1/audio-analysis/3jag...       263227
# 1008  https://api.spotify.com/v1/audio-analysis/0V3w...       200690
# 1009  https://api.spotify.com/v1/audio-analysis/6sZo...       225789
# 1010  https://api.spotify.com/v1/audio-analysis/4FWb...       237200
# 1011  https://api.spotify.com/v1/audio-analysis/4dVb...       260027
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1007               4
# 1008               4
# 1009               4
# 1010               4
# 1011               4
#
# [1004 rows x 20 columns]

# %%
# Selecciona solo las columnas numéricas para escalar
numeric_columns = data.select_dtypes(include=['int', 'float']).columns

# Escala los datos
scaler = StandardScaler()
X_prep = scaler.fit_transform(data[numeric_columns])

# %%
# Crea una instancia de KMeans
kmeans = KMeans(n_clusters=6, random_state=42)

# Ajusta el modelo KMeans a los datos escalados
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
# predecir |  asignar clusters:
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([4, 1, 1, ..., 1, 4, 4])

# %%
# ver el tamaño de los clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    338
# 1    195
# 2     45
# 3    168
# 4    229
# 5     29
# Name: count, dtype: int64

# %%
# Explore the cluster assignment in the original dataset
X_df = data
X_df["cluster"] = clusters
X_df.head()

X_df['cluster'] = X_df['cluster'].apply(lambda x: 0 if x == 1 else 1 if x == 2 else 2)
X_df
# Out:
#                              song         artist  danceability  energy  key  \
# 0                    Don't Change           INXS         0.206   0.810    9
# 1                            Halo        Beyoncé         0.508   0.720   11
# 2                    It's My Life       Bon Jovi         0.551   0.913    0
# 3           Where Did Our Love Go   The Supremes         0.566   0.490    0
# 4                  Ordinary World    Duran Duran         0.472   0.652    1
# ...                           ...            ...           ...     ...  ...
# 1007                      Work It  Missy Elliott         0.884   0.677    1
# 1008                    Anti-Hero   Taylor Swift         0.637   0.643    4
# 1009  Never Gonna Not Dance Again           P!nk         0.668   0.802    5
# 1010                    TRUSTFALL           P!nk         0.636   0.888    8
# 1011                      My Hero   Foo Fighters         0.398   0.927    9
#
#       loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0       -6.492     1       0.0423      0.000059          0.064400  ...
# 1       -5.908     0       0.0628      0.272000          0.000000  ...
# 2       -4.063     0       0.0466      0.026300          0.000013  ...
# 3      -10.867     1       0.0414      0.791000          0.000014  ...
# 4      -10.171     0       0.0305      0.013100          0.000011  ...
# ...        ...   ...          ...           ...               ...  ...
# 1007    -5.603     1       0.2830      0.077800          0.000000  ...
# 1008    -6.571     1       0.0519      0.130000          0.000002  ...
# 1009    -4.005     0       0.0917      0.027300          0.000000  ...
# 1010    -3.889     1       0.0945      0.001620          0.000216  ...
# 1011    -4.212     1       0.0567      0.000062          0.000177  ...
#
#       valence    tempo            type                      id  \
# 0       0.155  163.552  audio_features  2j7z87EnqB1NFQts2db0VR
# 1       0.472   79.983  audio_features  4JehYebiI9JE8sR8MisGVb
# 2       0.544  119.992  audio_features  0v1XpBHnsbkCn7iJ9Ucr1l
# 3       0.847  134.934  audio_features  69RH84na5iUNwrwxpgjC5j
# 4       0.401  140.124  audio_features  0wokCRaKD0zPNhMRXAgVsr
# ...       ...      ...             ...                     ...
# 1007    0.584  101.868  audio_features  3jagJCUbdqhDSPuxP8cAqF
# 1008    0.533   97.008  audio_features  0V3wPSX9ygBnCm8psDIegu
# 1009    0.769  113.796  audio_features  6sZo5nJIsFWXefRCCexpx0
# 1010    0.250  122.032  audio_features  4FWbsd91QSvgr1dSWwW51e
# 1011    0.311   77.106  audio_features  4dVbhS6OiYvFikshyaQaCN
#
#                                        uri  \
# 0     spotify:track:2j7z87EnqB1NFQts2db0VR
# 1     spotify:track:4JehYebiI9JE8sR8MisGVb
# 2     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l
# 3     spotify:track:69RH84na5iUNwrwxpgjC5j
# 4     spotify:track:0wokCRaKD0zPNhMRXAgVsr
# ...                                    ...
# 1007  spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 1008  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1009  spotify:track:6sZo5nJIsFWXefRCCexpx0
# 1010  spotify:track:4FWbsd91QSvgr1dSWwW51e
# 1011  spotify:track:4dVbhS6OiYvFikshyaQaCN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2j7z87EnqB1N...
# 1     https://api.spotify.com/v1/tracks/4JehYebiI9JE...
# 2     https://api.spotify.com/v1/tracks/0v1XpBHnsbkC...
# 3     https://api.spotify.com/v1/tracks/69RH84na5iUN...
# 4     https://api.spotify.com/v1/tracks/0wokCRaKD0zP...
# ...                                                 ...
# 1007  https://api.spotify.com/v1/tracks/3jagJCUbdqhD...
# 1008  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1009  https://api.spotify.com/v1/tracks/6sZo5nJIsFWX...
# 1010  https://api.spotify.com/v1/tracks/4FWbsd91QSvg...
# 1011  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2j7z...      268200
# 1     https://api.spotify.com/v1/audio-analysis/4Jeh...      261640
# 2     https://api.spotify.com/v1/audio-analysis/0v1X...      224493
# 3     https://api.spotify.com/v1/audio-analysis/69RH...      153333
# 4     https://api.spotify.com/v1/audio-analysis/0wok...      340200
# ...                                                 ...         ...
# 1007  https://api.spotify.com/v1/audio-analysis/3jag...      263227
# 1008  https://api.spotify.com/v1/audio-analysis/0V3w...      200690
# 1009  https://api.spotify.com/v1/audio-analysis/6sZo...      225789
# 1010  https://api.spotify.com/v1/audio-analysis/4FWb...      237200
# 1011  https://api.spotify.com/v1/audio-analysis/4dVb...      260027
#
#       time_signature  cluster
# 0                  4        2
# 1                  4        0
# 2                  4        0
# 3                  4        2
# 4                  4        0
# ...              ...      ...
# 1007               4        2
# 1008               4        2
# 1009               4        0
# 1010               4        2
# 1011               4        2
#
# [1004 rows x 21 columns]

# %%
kmeans.inertia_
# Out:
# 8642.02905053068

# %%
import numpy as np

K = range(2, 20)

inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

inertia
# Out:
# [11541.77081282437,
#  10691.588217836326,
#  9932.53246338455,
#  9289.23036750361,
#  8673.641290230995,
#  8171.782077701431,
#  7647.303046196896,
#  7307.05100999624,
#  7039.525478491572,
#  6800.305470884321,
#  6574.087531834393,
#  6402.467161103688,
#  6249.832342208645,
#  6143.671968223141,
#  6018.500050438059,
#  5910.034569569563,
#  5858.1244589118105,
#  5729.406648496725]

# %%
# "performance metric"
kmeans.inertia_
# Out:
# 5729.406648496725

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.title('Inertia Methond')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %%
# Comprobando el número óptimo de clústeres

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X_prep)
    wcss.append(kmeans.inertia_)

# %%
inertia = []
silhouette_scores = []
ranges = range(2,15)

for k in ranges:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10).fit(X_prep)
    inertia.append(kmeans.inertia_)

    silhouette_avg = silhouette_score(X_prep, kmeans.labels_)
    silhouette_scores.append(silhouette_avg)

plt.plot(ranges,inertia, marker = "o")
plt.show()

plt.plot(ranges, silhouette_scores, marker="o")

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method - Optimal Number of Clusters')
plt.show()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer


model = KMeans(n_clusters=3)  
visualizer = KElbowVisualizer(model, k=(1,11))
visualizer.fit(X_prep)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
#Plotting los clusters y sus  centroides
pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_prep)
pca_centers = pca.transform(kmeans.cluster_centers_)
plt.figure(figsize=(10, 10))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmeans.labels_, s=50, cmap='viridis')
plt.scatter(pca_centers[:, 0], pca_centers[:, 1], c='red', s=200, alpha=0.5)
plt.title('KMeans Clusters')
plt.show()

# %%
# Intentando agrupar los datos usando DBSCAN

dbscan = DBSCAN(eps=0.5, min_samples=2)
dbscan.fit(X_prep)
data['cluster_dbscan'] = dbscan.labels_

data['cluster_dbscan'].value_counts()
# Out:
# cluster_dbscan
# -1    1002
#  0       2
# Name: count, dtype: int64

# %%
# Intentando agrupar los datos usando una Gaussian Mixture
gmm = GaussianMixture(n_components=5)
gmm.fit(X_prep)
data['cluster_gmm'] = gmm.predict(X_prep)

data['cluster_gmm'].value_counts()
# Out:
# cluster_gmm
# 4    584
# 2    160
# 0    120
# 1    108
# 3     32
# Name: count, dtype: int64

# %%
#Plotting the clusters y centroides
plt.figure(figsize=(10, 10))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=gmm.predict(X_prep), s=50, cmap='viridis')
plt.title('Gaussian Mixture Clusters')
plt.show()

# %%
# Creando una función para buscar una canción en el dataframe y devolver el clúster

def get_cluster(song):
    try:
        return data[data['song'] == song]['cluster'].values[0]
    except:
        return None

# %%
#Testing the function
get_cluster('Anti-Hero')
# Out:
# 2

# %%
import pandas as pd
import tkinter as tk
from tkinter import messagebox
from sklearn.metrics.pairwise import cosine_similarity

# Calcular similitud entre clusters
clusters = data['cluster'].unique()
cluster_features_matrix = pd.get_dummies(data['cluster']).values

# %%
# Calcular similitud entre los clusters
cosine_sim = cosine_similarity(cluster_features_matrix)

# %%
data['song_artist'] = data['song'] + ' - ' + data['artist']

# %%
#Función para obtener recomendaciones basadas en clusters y filtrar por una palabra específica
def get_cluster_recommendations(song, cosine_sim=cosine_sim):
    data['song'] = data['song'].str.lower()  # Convertir nombres de canciones a minúsculas
    data['song'] = data['song'].str.replace('&', 'and')  # Reemplazar '&' por 'y'

    input_song = song.lower()  # Convertir nombre de la canción ingresada a minúsculas
    input_song = input_song.replace('&', 'and')  # Reemplazar '&' por 'y' en la canción ingresada

    song_cluster = data[data['song'] == input_song]['cluster'].values[0]
    sim_scores = list(cosine_sim[song_cluster])
    sim_scores = sorted(enumerate(sim_scores), key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Excluir la canción de entrada
    song_indices = [i[0] for i in sim_scores]

    return data['song_artist'].iloc[song_indices]

# %%
#Función para manejar la solicitud del usuario
def recommend_song():
    input_song = entry_song.get()
    if input_song:
        try:
            recommendations = get_cluster_recommendations(input_song)
            messagebox.showinfo("Recommendations", "\n".join(recommendations))
        except IndexError:
            messagebox.showerror("Error", "The song is not found in the database!")
    else:
        messagebox.showerror("Error", "Please enter a song title!")

# %%
#Configuración de la interfaz
root = tk.Tk()
root.title("Song Recommender")

label_instructions = tk.Label(root, text="Insert a song title:")
label_instructions.pack()

entry_song = tk.Entry(root, width=50)
entry_song.pack()

button_recommend = tk.Button(root, text="Get recommendations", command=recommend_song)
button_recommend.pack()

root.mainloop()
